# %% [markdown]
# <a href="https://colab.research.google.com/github/Escaladis/Analyse-des-donnees/blob/main/Video_covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("G:\BigData\Projets\DataSet\Covid_geo.xlsx")

# %%
df.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3 2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4 2020-12-10   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# 2                                           6.868768
# 3                                           7.134266
# 4                                           6.968658

# %%
# data cleanning
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
df=df[['dateRep', 'countriesAndTerritories', 'cases']]

# %%
df.head()
# Out:
#      dateRep countriesAndTerritories  cases
# 0 2020-12-14             Afghanistan    746
# 1 2020-12-13             Afghanistan    298
# 2 2020-12-12             Afghanistan    113
# 3 2020-12-11             Afghanistan     63
# 4 2020-12-10             Afghanistan    202

# %%
df.dtypes
# Out:
# dateRep                    datetime64[ns]
# countriesAndTerritories            object
# cases                               int64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['dateRep'], dayfirst=True)

# %%
df=df.drop(columns=["dateRep"])
df.head()
# Out:
#   countriesAndTerritories  cases       date
# 0             Afghanistan    746 2020-12-14
# 1             Afghanistan    298 2020-12-13
# 2             Afghanistan    113 2020-12-12
# 3             Afghanistan     63 2020-12-11
# 4             Afghanistan    202 2020-12-10

# %%
df.head()
# Out:
#   countriesAndTerritories  cases       date
# 0             Afghanistan    746 2020-12-14
# 1             Afghanistan    298 2020-12-13
# 2             Afghanistan    113 2020-12-12
# 3             Afghanistan     63 2020-12-11
# 4             Afghanistan    202 2020-12-10

# %%
df['total_cases'] = df.sort_values('date').groupby('countriesAndTerritories').cumsum().sort_index()
df.head()
# Out:
#   countriesAndTerritories  cases       date  total_cases
# 0             Afghanistan    746 2020-12-14        49273
# 1             Afghanistan    298 2020-12-13        48527
# 2             Afghanistan    113 2020-12-12        48229
# 3             Afghanistan     63 2020-12-11        48116
# 4             Afghanistan    202 2020-12-10        48053

# %%
df.head()
# Out:
#   countriesAndTerritories  cases       date  total_cases
# 0             Afghanistan    746 2020-12-14        49273
# 1             Afghanistan    298 2020-12-13        48527
# 2             Afghanistan    113 2020-12-12        48229
# 3             Afghanistan     63 2020-12-11        48116
# 4             Afghanistan    202 2020-12-10        48053

# %%
df = df[['date', 'countriesAndTerritories', 'total_cases']]
df = df.rename(columns={'countriesAndTerritories': 'country'})
df
# Out:
#             date      country  total_cases
# 0     2020-12-14  Afghanistan        49273
# 1     2020-12-13  Afghanistan        48527
# 2     2020-12-12  Afghanistan        48229
# 3     2020-12-11  Afghanistan        48116
# 4     2020-12-10  Afghanistan        48053
# ...          ...          ...          ...
# 61895 2020-03-25     Zimbabwe            2
# 61896 2020-03-24     Zimbabwe            2
# 61897 2020-03-23     Zimbabwe            2
# 61898 2020-03-22     Zimbabwe            2
# 61899 2020-03-21     Zimbabwe            1
#
# [61900 rows x 3 columns]

# %%
df = pd.pivot_table(df, index=['date'], columns=['country'], values=['total_cases'])
df
# Out:
#            total_cases                                              \
# country    Afghanistan  Albania  Algeria Andorra   Angola Anguilla
# date
# 2019-12-31         0.0      NaN      0.0     NaN      NaN      NaN
# 2020-01-01         0.0      NaN      0.0     NaN      NaN      NaN
# 2020-01-02         0.0      NaN      0.0     NaN      NaN      NaN
# 2020-01-03         0.0      NaN      0.0     NaN      NaN      NaN
# 2020-01-04         0.0      NaN      0.0     NaN      NaN      NaN
# ...                ...      ...      ...     ...      ...      ...
# 2020-12-10     48053.0  45188.0  90014.0  7162.0  15804.0     10.0
# 2020-12-11     48116.0  46061.0  90579.0  7190.0  15925.0     10.0
# 2020-12-12     48229.0  46863.0  91121.0  7236.0  16061.0     10.0
# 2020-12-13     48527.0  47742.0  91638.0  7288.0  16161.0     10.0
# 2020-12-14     49273.0  48530.0  92102.0  7338.0  16188.0     10.0
#
#                                                              ...          \
# country    Antigua_and_Barbuda  Argentina   Armenia   Aruba  ... Uruguay
# date                                                         ...
# 2019-12-31                 NaN        NaN       0.0     NaN  ...     NaN
# 2020-01-01                 NaN        NaN       0.0     NaN  ...     NaN
# 2020-01-02                 NaN        NaN       0.0     NaN  ...     NaN
# 2020-01-03                 NaN        NaN       0.0     NaN  ...     NaN
# 2020-01-04                 NaN        NaN       0.0     NaN  ...     NaN
# ...                        ...        ...       ...     ...  ...     ...
# 2020-12-10               146.0  1475222.0  145240.0  4996.0  ...  8104.0
# 2020-12-11               146.0  1482216.0  146317.0  5011.0  ...  8487.0
# 2020-12-12               147.0  1489328.0  147312.0  5031.0  ...  8849.0
# 2020-12-13               148.0  1494602.0  148325.0  5044.0  ...  9180.0
# 2020-12-14               148.0  1498160.0  148682.0  5049.0  ...  9708.0
#
#                                                                    \
# country    Uzbekistan Vanuatu Venezuela Vietnam Wallis_and_Futuna
# date
# 2019-12-31        NaN     NaN       NaN     0.0               NaN
# 2020-01-01        NaN     NaN       NaN     0.0               NaN
# 2020-01-02        NaN     NaN       NaN     0.0               NaN
# 2020-01-03        NaN     NaN       NaN     0.0               NaN
# 2020-01-04        NaN     NaN       NaN     0.0               NaN
# ...               ...     ...       ...     ...               ...
# 2020-12-10    74498.0     1.0  105852.0  1381.0               3.0
# 2020-12-11    74664.0     1.0  106280.0  1385.0               3.0
# 2020-12-12    74811.0     1.0  106715.0  1391.0               3.0
# 2020-12-13    74956.0     1.0  106715.0  1395.0               3.0
# 2020-12-14    75094.0     1.0  107177.0  1397.0               3.0
#
#
# country    Western_Sahara   Yemen   Zambia Zimbabwe
# date
# 2019-12-31            NaN     NaN      NaN      NaN
# 2020-01-01            NaN     NaN      NaN      NaN
# 2020-01-02            NaN     NaN      NaN      NaN
# 2020-01-03            NaN     NaN      NaN      NaN
# 2020-01-04            NaN     NaN      NaN      NaN
# ...                   ...     ...      ...      ...
# 2020-12-10          766.0  2079.0  18062.0  11007.0
# 2020-12-11          766.0  2081.0  18091.0  11081.0
# 2020-12-12          766.0  2082.0  18161.0  11162.0
# 2020-12-13          766.0  2083.0  18217.0  11219.0
# 2020-12-14          766.0  2083.0  18274.0  11246.0
#
# [350 rows x 214 columns]

# %%
df.columns
# Out:
# MultiIndex([('total_cases',         'Afghanistan'),
#             ('total_cases',             'Albania'),
#             ('total_cases',             'Algeria'),
#             ('total_cases',             'Andorra'),
#             ('total_cases',              'Angola'),
#             ('total_cases',            'Anguilla'),
#             ('total_cases', 'Antigua_and_Barbuda'),
#             ('total_cases',           'Argentina'),
#             ('total_cases',             'Armenia'),
#             ('total_cases',               'Aruba'),
#             ...
#             ('total_cases',             'Uruguay'),
#             ('total_cases',          'Uzbekistan'),
#             ('total_cases',             'Vanuatu'),
#             ('total_cases',           'Venezuela'),
#             ('total_cases',             'Vietnam'),
#             ('total_cases',   'Wallis_and_Futuna'),
#             ('total_cases',      'Western_Sahara'),
#             ('total_cases',               'Yemen'),
#             ('total_cases',              'Zambia'),
#             ('total_cases',            'Zimbabwe')],
#            names=[None, 'country'], length=214)

# %%
df.index.name = None
df.columns = [col[1] for col in df.columns]
df
# Out:
#             Afghanistan  Albania  Algeria  Andorra   Angola  Anguilla  \
# 2019-12-31          0.0      NaN      0.0      NaN      NaN       NaN
# 2020-01-01          0.0      NaN      0.0      NaN      NaN       NaN
# 2020-01-02          0.0      NaN      0.0      NaN      NaN       NaN
# 2020-01-03          0.0      NaN      0.0      NaN      NaN       NaN
# 2020-01-04          0.0      NaN      0.0      NaN      NaN       NaN
# ...                 ...      ...      ...      ...      ...       ...
# 2020-12-10      48053.0  45188.0  90014.0   7162.0  15804.0      10.0
# 2020-12-11      48116.0  46061.0  90579.0   7190.0  15925.0      10.0
# 2020-12-12      48229.0  46863.0  91121.0   7236.0  16061.0      10.0
# 2020-12-13      48527.0  47742.0  91638.0   7288.0  16161.0      10.0
# 2020-12-14      49273.0  48530.0  92102.0   7338.0  16188.0      10.0
#
#             Antigua_and_Barbuda  Argentina   Armenia   Aruba  ...  Uruguay  \
# 2019-12-31                  NaN        NaN       0.0     NaN  ...      NaN
# 2020-01-01                  NaN        NaN       0.0     NaN  ...      NaN
# 2020-01-02                  NaN        NaN       0.0     NaN  ...      NaN
# 2020-01-03                  NaN        NaN       0.0     NaN  ...      NaN
# 2020-01-04                  NaN        NaN       0.0     NaN  ...      NaN
# ...                         ...        ...       ...     ...  ...      ...
# 2020-12-10                146.0  1475222.0  145240.0  4996.0  ...   8104.0
# 2020-12-11                146.0  1482216.0  146317.0  5011.0  ...   8487.0
# 2020-12-12                147.0  1489328.0  147312.0  5031.0  ...   8849.0
# 2020-12-13                148.0  1494602.0  148325.0  5044.0  ...   9180.0
# 2020-12-14                148.0  1498160.0  148682.0  5049.0  ...   9708.0
#
#             Uzbekistan  Vanuatu  Venezuela  Vietnam  Wallis_and_Futuna  \
# 2019-12-31         NaN      NaN        NaN      0.0                NaN
# 2020-01-01         NaN      NaN        NaN      0.0                NaN
# 2020-01-02         NaN      NaN        NaN      0.0                NaN
# 2020-01-03         NaN      NaN        NaN      0.0                NaN
# 2020-01-04         NaN      NaN        NaN      0.0                NaN
# ...                ...      ...        ...      ...                ...
# 2020-12-10     74498.0      1.0   105852.0   1381.0                3.0
# 2020-12-11     74664.0      1.0   106280.0   1385.0                3.0
# 2020-12-12     74811.0      1.0   106715.0   1391.0                3.0
# 2020-12-13     74956.0      1.0   106715.0   1395.0                3.0
# 2020-12-14     75094.0      1.0   107177.0   1397.0                3.0
#
#             Western_Sahara   Yemen   Zambia  Zimbabwe
# 2019-12-31             NaN     NaN      NaN       NaN
# 2020-01-01             NaN     NaN      NaN       NaN
# 2020-01-02             NaN     NaN      NaN       NaN
# 2020-01-03             NaN     NaN      NaN       NaN
# 2020-01-04             NaN     NaN      NaN       NaN
# ...                    ...     ...      ...       ...
# 2020-12-10           766.0  2079.0  18062.0   11007.0
# 2020-12-11           766.0  2081.0  18091.0   11081.0
# 2020-12-12           766.0  2082.0  18161.0   11162.0
# 2020-12-13           766.0  2083.0  18217.0   11219.0
# 2020-12-14           766.0  2083.0  18274.0   11246.0
#
# [350 rows x 214 columns]

# %%
df = df.fillna(0).astype(int)
df
# Out:
#             Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 2019-12-31            0        0        0        0       0         0
# 2020-01-01            0        0        0        0       0         0
# 2020-01-02            0        0        0        0       0         0
# 2020-01-03            0        0        0        0       0         0
# 2020-01-04            0        0        0        0       0         0
# ...                 ...      ...      ...      ...     ...       ...
# 2020-12-10        48053    45188    90014     7162   15804        10
# 2020-12-11        48116    46061    90579     7190   15925        10
# 2020-12-12        48229    46863    91121     7236   16061        10
# 2020-12-13        48527    47742    91638     7288   16161        10
# 2020-12-14        49273    48530    92102     7338   16188        10
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  Uruguay  \
# 2019-12-31                    0          0        0      0  ...        0
# 2020-01-01                    0          0        0      0  ...        0
# 2020-01-02                    0          0        0      0  ...        0
# 2020-01-03                    0          0        0      0  ...        0
# 2020-01-04                    0          0        0      0  ...        0
# ...                         ...        ...      ...    ...  ...      ...
# 2020-12-10                  146    1475222   145240   4996  ...     8104
# 2020-12-11                  146    1482216   146317   5011  ...     8487
# 2020-12-12                  147    1489328   147312   5031  ...     8849
# 2020-12-13                  148    1494602   148325   5044  ...     9180
# 2020-12-14                  148    1498160   148682   5049  ...     9708
#
#             Uzbekistan  Vanuatu  Venezuela  Vietnam  Wallis_and_Futuna  \
# 2019-12-31           0        0          0        0                  0
# 2020-01-01           0        0          0        0                  0
# 2020-01-02           0        0          0        0                  0
# 2020-01-03           0        0          0        0                  0
# 2020-01-04           0        0          0        0                  0
# ...                ...      ...        ...      ...                ...
# 2020-12-10       74498        1     105852     1381                  3
# 2020-12-11       74664        1     106280     1385                  3
# 2020-12-12       74811        1     106715     1391                  3
# 2020-12-13       74956        1     106715     1395                  3
# 2020-12-14       75094        1     107177     1397                  3
#
#             Western_Sahara  Yemen  Zambia  Zimbabwe
# 2019-12-31               0      0       0         0
# 2020-01-01               0      0       0         0
# 2020-01-02               0      0       0         0
# 2020-01-03               0      0       0         0
# 2020-01-04               0      0       0         0
# ...                    ...    ...     ...       ...
# 2020-12-10             766   2079   18062     11007
# 2020-12-11             766   2081   18091     11081
# 2020-12-12             766   2082   18161     11162
# 2020-12-13             766   2083   18217     11219
# 2020-12-14             766   2083   18274     11246
#
# [350 rows x 214 columns]

# %%
df['Cases_on_an_international_conveyance_Japan']
# Out:
# 2019-12-31    0
# 2020-01-01    0
# 2020-01-02    0
# 2020-01-03    0
# 2020-01-04    0
#              ..
# 2020-12-10    0
# 2020-12-11    0
# 2020-12-12    0
# 2020-12-13    0
# 2020-12-14    0
# Name: Cases_on_an_international_conveyance_Japan, Length: 350, dtype: int32

# %%
df = df.drop(columns=['Cases_on_an_international_conveyance_Japan'])
df
# Out:
#             Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# 2019-12-31            0        0        0        0       0         0
# 2020-01-01            0        0        0        0       0         0
# 2020-01-02            0        0        0        0       0         0
# 2020-01-03            0        0        0        0       0         0
# 2020-01-04            0        0        0        0       0         0
# ...                 ...      ...      ...      ...     ...       ...
# 2020-12-10        48053    45188    90014     7162   15804        10
# 2020-12-11        48116    46061    90579     7190   15925        10
# 2020-12-12        48229    46863    91121     7236   16061        10
# 2020-12-13        48527    47742    91638     7288   16161        10
# 2020-12-14        49273    48530    92102     7338   16188        10
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  Uruguay  \
# 2019-12-31                    0          0        0      0  ...        0
# 2020-01-01                    0          0        0      0  ...        0
# 2020-01-02                    0          0        0      0  ...        0
# 2020-01-03                    0          0        0      0  ...        0
# 2020-01-04                    0          0        0      0  ...        0
# ...                         ...        ...      ...    ...  ...      ...
# 2020-12-10                  146    1475222   145240   4996  ...     8104
# 2020-12-11                  146    1482216   146317   5011  ...     8487
# 2020-12-12                  147    1489328   147312   5031  ...     8849
# 2020-12-13                  148    1494602   148325   5044  ...     9180
# 2020-12-14                  148    1498160   148682   5049  ...     9708
#
#             Uzbekistan  Vanuatu  Venezuela  Vietnam  Wallis_and_Futuna  \
# 2019-12-31           0        0          0        0                  0
# 2020-01-01           0        0          0        0                  0
# 2020-01-02           0        0          0        0                  0
# 2020-01-03           0        0          0        0                  0
# 2020-01-04           0        0          0        0                  0
# ...                ...      ...        ...      ...                ...
# 2020-12-10       74498        1     105852     1381                  3
# 2020-12-11       74664        1     106280     1385                  3
# 2020-12-12       74811        1     106715     1391                  3
# 2020-12-13       74956        1     106715     1395                  3
# 2020-12-14       75094        1     107177     1397                  3
#
#             Western_Sahara  Yemen  Zambia  Zimbabwe
# 2019-12-31               0      0       0         0
# 2020-01-01               0      0       0         0
# 2020-01-02               0      0       0         0
# 2020-01-03               0      0       0         0
# 2020-01-04               0      0       0         0
# ...                    ...    ...     ...       ...
# 2020-12-10             766   2079   18062     11007
# 2020-12-11             766   2081   18091     11081
# 2020-12-12             766   2082   18161     11162
# 2020-12-13             766   2083   18217     11219
# 2020-12-14             766   2083   18274     11246
#
# [350 rows x 213 columns]

# %%
df.columns = [col.replace('_', ' ') for col in df.columns]

# %%
country_reserved = set()
for index, row in df.iterrows():
    country_reserved |= set(row[row > 0].sort_values(ascending=False).head(10).index)
df = df[list(country_reserved)]

# %%
df.head()
# Out:
#             Malaysia  China  Argentina  South Africa  Switzerland  \
# 2019-12-31         0     27          0             0            0
# 2020-01-01         0     27          0             0            0
# 2020-01-02         0     27          0             0            0
# 2020-01-03         0     44          0             0            0
# 2020-01-04         0     44          0             0            0
#
#             United Kingdom  Japan  Colombia  Vietnam  Mexico  ...  \
# 2019-12-31               0      0         0        0       0  ...
# 2020-01-01               0      0         0        0       0  ...
# 2020-01-02               0      0         0        0       0  ...
# 2020-01-03               0      0         0        0       0  ...
# 2020-01-04               0      0         0        0       0  ...
#
#             South Korea  Belgium  Russia  Taiwan  Kuwait  Iran  Turkey  \
# 2019-12-31            0        0       0       0       0     0       0
# 2020-01-01            0        0       0       0       0     0       0
# 2020-01-02            0        0       0       0       0     0       0
# 2020-01-03            0        0       0       0       0     0       0
# 2020-01-04            0        0       0       0       0     0       0
#
#             Australia  United States of America  France
# 2019-12-31          0                         0       0
# 2020-01-01          0                         0       0
# 2020-01-02          0                         0       0
# 2020-01-03          0                         0       0
# 2020-01-04          0                         0       0
#
# [5 rows x 30 columns]

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(
    df=df,
    filename='G:\BigData\Projets\covid-19.mp4',
    n_bars=10,
    period_fmt='%B %d, %Y',
    title='Cas confirmés de COVID-19 par pays'
)
# Out:
# C:\Users\Ilyas\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\Ilyas\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
